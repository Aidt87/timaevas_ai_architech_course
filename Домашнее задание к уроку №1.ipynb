# %%
import numpy as np

# %% [markdown]
# Решение первой задачи:
# Результат: matrix([[10]])

# %%
A = np.matrix([6, -8, 3])

B = np.matrix([[1],
               [1],
               [4]])

A * B
# Out:
# matrix([[10]])

# %% [markdown]
# Решение второй задачи:
# Результат:  matrix([[  -4,  -13],
#                     [ 104, -102],
#                     [ -24,   12],
#                     [  -4,   -3]])

# %%
C = np.matrix([[-3, -7],
               [-10, 6],
               [0, -6],
               [-1, -3]])

D = np.matrix([[-8, 9],
               [4, -2]])

C * D
# Out:
# matrix([[  -4,  -13],
#         [ 104, -102],
#         [ -24,   12],
#         [  -4,   -3]])
